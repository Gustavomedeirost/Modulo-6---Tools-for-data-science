# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# 2-title.png ![# Data Science Tools and Ecosystem.png](attachment:8ea95570-755b-4d70-ba1d-68b6c7adeafd.png)

# %% [markdown]
# # Neste notebook, as Ferramentas e Ecossistema de Ciência de Dados são resumidos.

# %% [markdown]
# 3-intro.png ![3-intro.png](attachment:dab771d7-a8be-4186-a04d-954620a25e73.png)

# %% [markdown]
# # Algumas das linguagens populares que os Cientistas de Dados usam são:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# 4-dslanguages.png ![4-dslanguages.png](attachment:7c07afee-3b03-473a-b37e-916fd0d32573.png)

# %% [markdown]
# # Algumas das bibliotecas comumente usadas por Cientistas de Dados incluem:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# 5-dslibraries.png ![5-dslibraries.png](attachment:d7b468a1-0316-4324-bb73-a3988d42b807.png)

# %% [markdown]
# # Ferramentas de Ciência de Dados
# 1. Jupyter Notebook
# 2. RStudio
# 3. Apache Spark

# %% [markdown]
# 6-dstools.png ![6-dstools.png](attachment:718e17d7-643b-4fd2-a9c6-a0d9515e633a.png)

# %% [markdown]
# ### Abaixo estão alguns exemplos de avaliação de expressões aritméticas em Python.

# %% [markdown]
# ![7-introarithmetic.png](attachment:f0173ee6-aa68-4933-8d87-70ce0e61b5b2.png) 7-introarithmetic.png

# %% [markdown]
# # Isso converterá 200 minutos em horas dividindo por 60
# 200 / 60

# %% [markdown]
# ![9-hourstominutes.png](attachment:9695e268-3973-42bf-bdcb-beec58f25a53.png) 9-hourstominutes.png

# %% [markdown]
# **Objetivos:**
# - Listar linguagens populares para Ciência de Dados
# - Listar bibliotecas usadas por Cientistas de Dados
# - Criar tabelas com ferramentas
# - Executar operações aritméticas em Python
# - Converter unidades de tempo

# %% [markdown]
# ![10-objectives.png](attachment:16be8c2d-b7b2-4f2d-abdc-a75367dabdc1.png) 10-objectives.png

# %% [markdown]
# ## Autor
# Gustavo Medeiros

# %% [markdown]
# 11-authordetails.png ![11-authordetails.png](attachment:b06b157c-9ab2-4abb-b4a2-985e9dd1c997.png)
